# %%
import gym
from gym.spaces import Discrete, Box
import numpy as np
import random

# %%
import socket
from time import sleep
import sys
import json


class ClientCommunication:
    ue_tasks = {"step": 0,
                "reset": 1,
                "state": 2,
                "reward": 3,
                "is_done": 4}
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s_notify = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    def __init__(self, host, port):
        self.host = host
        self.port = port

        try:
            self.s.connect((self.host, self.port))
            print("connected! (main)")
        except:
            print("connection failed or interrupted (main)")

        try:
            self.s_notify.connect((self.host, self.port - 1))
            print("connected! (notify)")
        except:
            print("connection failed or interrupted (notify)")

    def step(self, action):
        # try:
            data = {'id': self.ue_tasks['step'], 'action': []}
            if not hasattr(action, '__iter__'):
                data['action'] = [float(action)]
            else:
                try:
                    data['action'] = list(action.tolist())
                except:
                    try:
                        data['action'] = list(action)
                    except:
                        data['action'] = [action]
                for i in range(len(data['action'])):
                    data['action'][i] = float(data['action'][i] )
            print(data)
            self.s.sendall(bytes(json.dumps(data), encoding="utf-8"))
            print("post: step")

            self.wait()
            info_ = {}
            observation_ = self.state()
            reward_ = self.reward()
            done_ = self.is_done()
            return observation_, reward_, done_, info_
        # except:
        #     print("step: connection failed or interrupted")

    def reset(self):
        try:
            data = {'id': self.ue_tasks['reset'], 'action': [0]}
            self.s.sendall(bytes(json.dumps(data), encoding="utf-8"))
            print("post: reset")

            self.wait()
            return self.state()

        except:
            print("reset: connection failed or interrupted")

    def state(self):
        try:
            data = {'id': self.ue_tasks['state'], 'action': [0]}
            self.s.sendall(bytes(json.dumps(data), encoding="utf-8"))

            received = self.s_notify.recv(2048)
            received = received.decode('utf-8')
            received = json.loads(received)
            print("get: state")
            print(received['state'][0])
            return received['state'][0]
        except:
            print("state: connection failed or interrupted")

    def reward(self):
        try:
            data = {'id': self.ue_tasks['reward'], 'action': [0]}
            self.s.sendall(bytes(json.dumps(data), encoding="utf-8"))

            received = self.s_notify.recv(2048)
            received = received.decode('utf-8')
            received = json.loads(received)
            print("get: reward")
            return received['reward']

        except:
            print("reward: connection failed or interrupted")

    def is_done(self):
        try:
            data = {'id': self.ue_tasks['is_done'], 'action': [0]}
            self.s.sendall(bytes(json.dumps(data), encoding="utf-8"))

            received = self.s_notify.recv(2048)
            received = received.decode('utf-8')
            received = json.loads(received)
            print("get: is_done")
            return received['isDone']
        except:
            print("is_done: connection failed or interrupted")

    def wait(self):
        received = 0
        while received != "1":
            received = self.s_notify.recv(32)
            received = received.decode("utf-8")
        #print("next")

# %%
class UnrealEnv(gym.Env):

    def __init__(self, host, port):
        #Actions: down, stay, up
        self.action_space = Discrete(5)
        #Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))

        self.client = ClientCommunication(host, port)
        #Set start temp
        #self.state = 38 + random.randint(-3, 3)

        # Set shower length
        #self.shower_length = 60

    def step(self, act):
        return self.client.step(act)

        # if 37 <= self.state <= 39:
        #     reward = 1
        # else:
        #     if self.state < 37:
        #         reward = -(37 - self.state)
        #     else:
        #         reward = (self.state - 39)
        #
        # if self.shower_length <= 0:
        #     done = True
        # else:
        #     done = False
        #
        # self.state += -1 + random.random() * (1 - (-1))
        #
        # info = {}
        #
        # return self.state, reward, done, info

    def render(self):
        pass

    @property
    def reward(self):
        return self.client.reward()

    @property
    def state(self):
        return self.client.state()

    @property
    def done(self):
        return self.client.is_done()

    def reset(self):
        return self.client.reset()

# %%
env = UnrealEnv("26.225.53.123", 7787)
# Out:
# connected! (main)
# connected! (notify)

# %%
# env.step(2)

# %%
# episodes = 10
# arr = []
# for episode in range(1, episodes + 1):
#     state = env.reset()
#     done = False
#     score = 0
#
#     while not done:
#         env.render()
#         action = env.action_space.sample()
#         n_state, reward, done, info = env.step(action)
#         score += reward
#     arr.append('Episode: {} Score {}'.format(episode, score))

# %%
# for el in arr:
#     print(el)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
states = env.observation_space.shape
actions = env.action_space.n

# %%
def build_model(states, actions):
    model = Sequential()
    model.add(Dense(32, activation='sigmoid', input_shape = states))
    model.add(Dense(8, activation = 'relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_96 (Dense)            (None, 32)                64
#
#  dense_97 (Dense)            (None, 8)                 264
#
#  dense_98 (Dense)            (None, 5)                 45
#
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers.legacy import Adam

from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
                   nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(learning_rate=1e-2), metrics=['mae'])
dqn.fit(env, nb_steps=1000, visualize=False, verbose=1)
# Out:
# Training for 1000 steps ...
# post: reset
# get: state
# 44
# Interval 1 (0 steps performed)
# {'id': 0, 'action': [1.0]}
# post: step
# get: state
# 43
# get: reward
# get: is_done
#     1/10000 [..............................] - ETA: 1:59:19 - reward: -1.0000{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 43
# get: reward
# get: is_done
#     2/10000 [..............................] - ETA: 10:59 - reward: -1.0000  {'id': 0, 'action': [1.0]}
# post: step
# get: state
# 43
# get: reward
# get: is_done
#     3/10000 [..............................] - ETA: 11:04 - reward: -1.0000{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 42
# get: reward
# get: is_done
#     4/10000 [..............................] - ETA: 11:06 - reward: -1.0000{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 42
# get: reward
# get: is_done
#     5/10000 [..............................] - ETA: 11:04 - reward: -1.0000{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 40
# get: reward
# get: is_done
#     6/10000 [..............................] - ETA: 11:05 - reward: -1.0000{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 41
# get: reward
# get: is_done
#     7/10000 [..............................] - ETA: 11:06 - reward: -1.0000{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 39
# get: reward
# get: is_done
#     8/10000 [..............................] - ETA: 11:29 - reward: -0.7500{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 40
# get: reward
# get: is_done
#     9/10000 [..............................] - ETA: 11:25 - reward: -0.7778{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 38
# get: reward
# get: is_done
#    10/10000 [..............................] - ETA: 11:23 - reward: -0.6000{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 39
# get: reward
# get: is_done
#    11/10000 [..............................] - ETA: 11:22 - reward: -0.4545{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 37
# get: reward
# get: is_done
#    12/10000 [..............................] - ETA: 48:27 - reward: -0.3333{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 36
# get: reward
# get: is_done
#    13/10000 [..............................] - ETA: 45:23 - reward: -0.3846{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 34
# get: reward
# get: is_done
#    14/10000 [..............................] - ETA: 42:46 - reward: -0.4286{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 33
# get: reward
# get: is_done
#    15/10000 [..............................] - ETA: 40:28 - reward: -0.4667{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 33
# get: reward
# get: is_done
#    16/10000 [..............................] - ETA: 38:30 - reward: -0.5000{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 32
# get: reward
# get: is_done
#    17/10000 [..............................] - ETA: 36:48 - reward: -0.5294{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 32
# get: reward
# get: is_done
#    18/10000 [..............................] - ETA: 35:16 - reward: -0.5556{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 29
# get: reward
# get: is_done
#    19/10000 [..............................] - ETA: 33:56 - reward: -0.5789{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 29
# get: reward
# get: is_done
#    20/10000 [..............................] - ETA: 32:43 - reward: -0.6000{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 28
# get: reward
# get: is_done
#    21/10000 [..............................] - ETA: 31:38 - reward: -0.6190{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 26
# get: reward
# get: is_done
#    22/10000 [..............................] - ETA: 30:40 - reward: -0.6364{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 28
# get: reward
# get: is_done
#    23/10000 [..............................] - ETA: 29:46 - reward: -0.6522{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 25
# get: reward
# get: is_done
#    24/10000 [..............................] - ETA: 28:57 - reward: -0.6667{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 24
# get: reward
# get: is_done
'id': 0, 'action': [0.0]}
# post: step
# get: state
# 34
# get: reward
# get: is_done
#   949/10000 [=>............................] - ETA: 10:32 - reward: -0.7998{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 36
# get: reward
# get: is_done
#   950/10000 [=>............................] - ETA: 10:31 - reward: -0.8000{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 36
# get: reward
# get: is_done
#   951/10000 [=>............................] - ETA: 10:31 - reward: -0.8002{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 37
# get: reward
# get: is_done
#   952/10000 [=>............................] - ETA: 10:31 - reward: -0.7983{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 35
# get: reward
# get: is_done
#   953/10000 [=>............................] - ETA: 10:31 - reward: -0.7985{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 35
# get: reward
# get: is_done
#   954/10000 [=>............................] - ETA: 10:31 - reward: -0.7987{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 37
# get: reward
# get: is_done
#   955/10000 [=>............................] - ETA: 10:31 - reward: -0.7969{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 35
# get: reward
# get: is_done
#   956/10000 [=>............................] - ETA: 10:31 - reward: -0.7971{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 35
# get: reward
# get: is_done
#   957/10000 [=>............................] - ETA: 10:31 - reward: -0.7973{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 36
# get: reward
# get: is_done
#   958/10000 [=>............................] - ETA: 10:31 - reward: -0.7975{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 38
# get: reward
# get: is_done
#   959/10000 [=>............................] - ETA: 10:30 - reward: -0.7956{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 39
# get: reward
# get: is_done
#   960/10000 [=>............................] - ETA: 10:30 - reward: -0.7937post: reset
# get: state
# 52
# {'id': 0, 'action': [4.0]}
# post: step
# get: state
# 54
# get: reward
# get: is_done
#   961/10000 [=>............................] - ETA: 10:31 - reward: -0.7940{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 54
# get: reward
# get: is_done
#   962/10000 [=>............................] - ETA: 10:30 - reward: -0.7942{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 55
# get: reward
# get: is_done
#   963/10000 [=>............................] - ETA: 10:30 - reward: -0.7944{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 52
# get: reward
# get: is_done
#   964/10000 [=>............................] - ETA: 10:30 - reward: -0.7946{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 53
# get: reward
# get: is_done
#   965/10000 [=>............................] - ETA: 10:30 - reward: -0.7948{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 50
# get: reward
# get: is_done
#   966/10000 [=>............................] - ETA: 10:30 - reward: -0.7950{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 52
# get: reward
# get: is_done
#   967/10000 [=>............................] - ETA: 10:30 - reward: -0.7952{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 49
# get: reward
# get: is_done
#   968/10000 [=>............................] - ETA: 10:30 - reward: -0.7955{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 49
# get: reward
# get: is_done
#   969/10000 [=>............................] - ETA: 10:30 - reward: -0.7957{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 48
# get: reward
# get: is_done
#   970/10000 [=>............................] - ETA: 10:30 - reward: -0.7959{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#   971/10000 [=>............................] - ETA: 10:30 - reward: -0.7961{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 45
# get: reward
# get: is_done
#   972/10000 [=>............................] - ETA: 10:29 - reward: -0.7963{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 48
# get: reward
# get: is_done
#   973/10000 [=>............................] - ETA: 10:29 - reward: -0.7965{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#   974/10000 [=>............................] - ETA: 10:29 - reward: -0.7967{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   975/10000 [=>............................] - ETA: 10:29 - reward: -0.7969{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   976/10000 [=>............................] - ETA: 10:29 - reward: -0.7971{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   977/10000 [=>............................] - ETA: 10:29 - reward: -0.7973{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   978/10000 [=>............................] - ETA: 10:29 - reward: -0.7975{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 45
# get: reward
# get: is_done
#   979/10000 [=>............................] - ETA: 10:29 - reward: -0.7978{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   980/10000 [=>............................] - ETA: 10:29 - reward: -0.7980{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 45
# get: reward
# get: is_done
#   981/10000 [=>............................] - ETA: 10:29 - reward: -0.7982{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   982/10000 [=>............................] - ETA: 10:29 - reward: -0.7984{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   983/10000 [=>............................] - ETA: 10:28 - reward: -0.7986{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   984/10000 [=>............................] - ETA: 10:28 - reward: -0.7988{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 44
# get: reward
# get: is_done
#   985/10000 [=>............................] - ETA: 10:28 - reward: -0.7990{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 43
# get: reward
# get: is_done
#   986/10000 [=>............................] - ETA: 10:28 - reward: -0.7992{'id': 0, 'action': [1.0]}
# post: step
# get: state
# 41
# get: reward
# get: is_done
#   987/10000 [=>............................] - ETA: 10:28 - reward: -0.7994{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 38
# get: reward
# get: is_done
#   988/10000 [=>............................] - ETA: 10:28 - reward: -0.7976{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 40
# get: reward
# get: is_done
#   989/10000 [=>............................] - ETA: 10:28 - reward: -0.7978{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 41
# get: reward
# get: is_done
# {'id': 0, 'action': [2.0]}
# post: step
# get: state
# 41
# get: reward
# get: is_done
#   991/10000 [=>............................] - ETA: 10:27 - reward: -0.7982{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 44
# get: reward
# get: is_done
#   992/10000 [=>............................] - ETA: 10:27 - reward: -0.7984{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#   993/10000 [=>............................] - ETA: 10:27 - reward: -0.7986{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 46
# get: reward
# get: is_done
#   994/10000 [=>............................] - ETA: 10:27 - reward: -0.7988{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#   995/10000 [=>............................] - ETA: 10:27 - reward: -0.7990{'id': 0, 'action': [4.0]}
# post: step
# get: state
# 50
# get: reward
# get: is_done
#   996/10000 [=>............................] - ETA: 10:27 - reward: -0.7992{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#   997/10000 [=>............................] - ETA: 10:27 - reward: -0.7994{'id': 0, 'action': [3.0]}
# post: step
# get: state
# 49
# get: reward
# get: is_done
#   998/10000 [=>............................] - ETA: 10:27 - reward: -0.7996{'id': 0, 'action': [2.0]}
# post: step
# get: state
# 50
# get: reward
# get: is_done
#   999/10000 [=>............................] - ETA: 10:27 - reward: -0.7998{'id': 0, 'action': [0.0]}
# post: step
# get: state
# 47
# get: reward
# get: is_done
#  1000/10000 [==>...........................] - ETA: 10:27 - reward: -0.8000done, took 70.348 seconds

# %%
_ = dqn.test(env, nb_episodes=15, visualize=True)
# Out:
# Testing for 15 episodes ...
# post: reset
# get: state
# 52
# {'id': 0, 'action': [3.0]}
# post: step
# get: state
# 52
# get: reward
# get: is_done
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[454], line 1
# ----> 1 _ = dqn.test(env, nb_episodes=15, visualize=True)
#
# File ~\PycharmProjects\RL_Module\venv\lib\site-packages\rl\core.py:352, in Agent.test(self, env, nb_episodes, action_repetition, callbacks, visualize, nb_max_episode_steps, nb_max_start_steps, start_step_policy, verbose)
#     350 if self.processor is not None:
#     351     observation, r, d, info = self.processor.process_step(observation, r, d, info)
# --> 352 callbacks.on_action_end(action)
#     353 reward += r
#     354 for key, value in info.items():
#
# File ~\PycharmProjects\RL_Module\venv\lib\site-packages\rl\callbacks.py:98, in CallbackList.on_action_end(self, action, logs)
#      96 for callback in self.callbacks:
#      97     if callable(getattr(callback, 'on_action_end', None)):
# ---> 98         callback.on_action_end(action, logs=logs)
#
# File ~\PycharmProjects\RL_Module\venv\lib\site-packages\rl\callbacks.py:360, in Visualizer.on_action_end(self, action, logs)
#     358 def on_action_end(self, action, logs):
#     359     """ Render environment at the end of each action """
# --> 360     self.env.render(mode='human')
#
# TypeError: UnrealEnv.render() got an unexpected keyword argument 'mode'

# %%
scores = dqn.test(env, nb_episodes=100, visualize=False)
print(np.mean(scores.history['episode_reward']))

# %%
print(np.mean(scores.history['episode_reward']))
